# %%
# coding:utf-8
# [0]必要なライブラリのインポート
import sys
sys.path.append('/usr/local/lib/python3.5/dist-packages')
import gym  # 倒立振子(cartpole)の実行環境
sys.path.remove('/usr/local/lib/python3.5/dist-packages')
import numpy as np
import time
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.utils import plot_model
from collections import deque
from gym import wrappers  # gymの画像保存
from keras import backend as K
import tensorflow as tf

# %%
# [1]損失関数の定義
# 損失関数にhuber関数を使用します 参考https://github.com/jaara/AI-blog/blob/master/CartPole-DQN.py
def huberloss(y_true, y_pred):
    err = y_true - y_pred
    cond = K.abs(err) < 1.0
    L2 = 0.5 * K.square(err)
    L1 = (K.abs(err) - 0.5)
    loss = tf.where(cond, L2, L1)  # Keras does not cover where function in tensorflow :-(
    return K.mean(loss)

# %%
# [2]Q関数をディープラーニングのネットワークをクラスとして定義
class QNetwork:
    def __init__(self, learning_rate=0.01, state_size=4, action_size=2, hidden_size=10):
        self.model = Sequential()
        self.model.add(Dense(hidden_size, activation='relu', input_dim=state_size))
        self.model.add(Dense(hidden_size, activation='relu'))
        self.model.add(Dense(action_size, activation='linear'))
        self.optimizer = Adam(lr=learning_rate)  # 誤差を減らす学習方法はAdam
        # self.model.compile(loss='mse', optimizer=self.optimizer)
        self.model.compile(loss=huberloss, optimizer=self.optimizer)

    # 重みの学習
    def replay(self, memory, batch_size, gamma, targetQN):
        inputs = np.zeros((batch_size, 4))
        targets = np.zeros((batch_size, 2))
        mini_batch = memory.sample(batch_size)

        for i, (state_b, action_b, reward_b, next_state_b) in enumerate(mini_batch):
            inputs[i:i + 1] = state_b
            target = reward_b

            if not (next_state_b == np.zeros(state_b.shape)).all(axis=1):
                # 価値計算（DDQNにも対応できるように、行動決定のQネットワークと価値観数のQネットワークは分離）
                retmainQs = self.model.predict(next_state_b)[0]
                next_action = np.argmax(retmainQs)  # 最大の報酬を返す行動を選択する
                target = reward_b + gamma * targetQN.model.predict(next_state_b)[0][next_action]

            targets[i] = self.model.predict(state_b)    # Qネットワークの出力
            targets[i][action_b] = target               # 教師信号

        self.model.fit(inputs, targets, epochs=1, verbose=0)  # epochsは訓練データの反復回数、verbose=0は表示なしの設定

# %%
# [3]Experience ReplayとFixed Target Q-Networkを実現するメモリクラス
class Memory:
    def __init__(self, max_size=1000):
        self.buffer = deque(maxlen=max_size)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        idx = np.random.choice(np.arange(len(self.buffer)), size=batch_size, replace=False)
        return [self.buffer[ii] for ii in idx]

    def len(self):
        return len(self.buffer)

# %%
# [4]カートの状態に応じて、行動を決定するクラス
class Actor:
    def get_action(self, state, episode, mainQN):   # [C]ｔ＋１での行動を返す
        # 徐々に最適行動のみをとる、ε-greedy法
        epsilon = 0.001 + 0.9 / (1.0+episode)

        if epsilon <= np.random.uniform(0, 1):
            retTargetQs = mainQN.model.predict(state)[0]
            action = np.argmax(retTargetQs)  # 最大の報酬を返す行動を選択する

        else:
            action = np.random.choice([0, 1])  # ランダムに行動する

        return action

# %%
# [5] メイン関数開始----------------------------------------------------
# [5.1] 初期設定--------------------------------------------------------
DQN_MODE = 1    # 1がDQN、0がDDQNです
LENDER_MODE = 1 # 0は学習後も描画なし、1は学習終了後に描画する

env = gym.make('CartPole-v0')
num_episodes = 299  # 総試行回数
max_number_of_steps = 200  # 1試行のstep数
goal_average_reward = 195  # この報酬を超えると学習終了
num_consecutive_iterations = 10  # 学習完了評価の平均計算を行う試行回数
total_reward_vec = np.zeros(num_consecutive_iterations)  # 各試行の報酬を格納
gamma = 0.99    # 割引係数
islearned = 0  # 学習が終わったフラグ
isrender = 0  # 描画フラグ
# ---
hidden_size = 16               # Q-networkの隠れ層のニューロンの数
learning_rate = 0.00001         # Q-networkの学習係数
memory_size = 10000            # バッファーメモリの大きさ
batch_size = 32                # Q-networkを更新するバッチの大記載
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
# [5.2]Qネットワークとメモリ、Actorの生成--------------------------------------------------------
mainQN = QNetwork(hidden_size=hidden_size, learning_rate=learning_rate)     # メインのQネットワーク
targetQN = QNetwork(hidden_size=hidden_size, learning_rate=learning_rate)   # 価値を計算するQネットワーク
# plot_model(mainQN.model, to_file='Qnetwork.png', show_shapes=True)        # Qネットワークの可視化
memory = Memory(max_size=memory_size)
actor = Actor()

# %%
# [5.3]メインルーチン--------------------------------------------------------
for episode in range(num_episodes):  # 試行数分繰り返す
    env.reset()  # cartPoleの環境初期化
    state, reward, done, _ = env.step(env.action_space.sample())  # 1step目は適当な行動をとる
    state = np.reshape(state, [1, 4])   # list型のstateを、1行4列の行列に変換
    episode_reward = 0

    
    targetQN.model.set_weights(mainQN.model.get_weights())

    for t in range(max_number_of_steps + 1):  # 1試行のループ
        if (islearned == 1) and LENDER_MODE:  # 学習終了したらcartPoleを描画する
            env.render()
            time.sleep(0.1)
            print(state[0, 0])  # カートのx位置を出力するならコメントはずす

        action = actor.get_action(state, episode, mainQN)   # 時刻tでの行動を決定する
        next_state, reward, done, info = env.step(action)   # 行動a_tの実行による、s_{t+1}, _R{t}を計算する
        next_state = np.reshape(next_state, [1, 4])     # list型のstateを、1行4列の行列に変換

        # 報酬を設定し、与える
        if done:
            next_state = np.zeros(state.shape)  # 次の状態s_{t+1}はない
            if t < 195:
                reward = -1  # 報酬クリッピング、報酬は1, 0, -1に固定
            else:
                reward = 1  # 立ったまま195step超えて終了時は報酬
        else:
            reward = 0  # 各ステップで立ってたら報酬追加（はじめからrewardに1が入っているが、明示的に表す）

        episode_reward += 1 # reward  # 合計報酬を更新

        memory.add((state, action, reward, next_state))     # メモリの更新する
        state = next_state  # 状態更新


        # Qネットワークの重みを学習・更新する replay
        if (memory.len() > batch_size) and not islearned:
            mainQN.replay(memory, batch_size, gamma, targetQN)

        if DQN_MODE:
            targetQN.model.set_weights(mainQN.model.get_weights())

        # 1施行終了時の処理
        if done:
            total_reward_vec = np.hstack((total_reward_vec[1:], episode_reward))  # 報酬を記録
            print('%d Episode finished after %f time steps / mean %f' % (episode, t + 1, total_reward_vec.mean()))
            break

    # 複数施行の平均報酬で終了を判断
    if total_reward_vec.mean() >= goal_average_reward:
        print('Episode %d train agent successfuly!' % episode)
        islearned = 1
        if isrender == 0:   # 学習済みフラグを更新
            isrender = 1

            # env = wrappers.Monitor(env, './movie/cartpoleDDQN')  # 動画保存する場合
            # 10エピソードだけでどんな挙動になるのか見たかったら、以下のコメントを外す
            # if episode>10:
            #    if isrender == 0:
            #        env = wrappers.Monitor(env, './movie/cartpole-experiment-1') #動画保存する場合
            #        isrender = 1
            #    islearned=1;
# Out:
# 0 Episode finished after 16.000000 time steps / mean 1.600000
# 1 Episode finished after 20.000000 time steps / mean 3.600000
# 2 Episode finished after 9.000000 time steps / mean 4.500000
# 3 Episode finished after 7.000000 time steps / mean 5.200000
# 4 Episode finished after 10.000000 time steps / mean 6.200000
# 5 Episode finished after 9.000000 time steps / mean 7.100000
# 6 Episode finished after 12.000000 time steps / mean 8.300000
# 7 Episode finished after 9.000000 time steps / mean 9.200000
# 8 Episode finished after 8.000000 time steps / mean 10.000000
# 9 Episode finished after 8.000000 time steps / mean 10.800000
# 10 Episode finished after 10.000000 time steps / mean 10.200000
# 11 Episode finished after 8.000000 time steps / mean 9.000000
# 12 Episode finished after 10.000000 time steps / mean 9.100000
# 13 Episode finished after 9.000000 time steps / mean 9.300000
# 14 Episode finished after 9.000000 time steps / mean 9.200000
# 15 Episode finished after 8.000000 time steps / mean 9.100000
# 16 Episode finished after 10.000000 time steps / mean 8.900000
# 17 Episode finished after 8.000000 time steps / mean 8.800000
# 18 Episode finished after 9.000000 time steps / mean 8.900000
# 19 Episode finished after 9.000000 time steps / mean 9.000000
# 20 Episode finished after 12.000000 time steps / mean 9.200000
# 21 Episode finished after 8.000000 time steps / mean 9.200000
# 22 Episode finished after 9.000000 time steps / mean 9.100000
# 23 Episode finished after 9.000000 time steps / mean 9.100000
# 24 Episode finished after 9.000000 time steps / mean 9.100000
# 25 Episode finished after 8.000000 time steps / mean 9.100000
# 26 Episode finished after 8.000000 time steps / mean 8.900000
# 27 Episode finished after 9.000000 time steps / mean 9.000000
# 28 Episode finished after 9.000000 time steps / mean 9.000000
# 29 Episode finished after 8.000000 time steps / mean 8.900000
# 30 Episode finished after 8.000000 time steps / mean 8.500000
# 31 Episode finished after 10.000000 time steps / mean 8.700000
# 32 Episode finished after 10.000000 time steps / mean 8.800000
# 33 Episode finished after 9.000000 time steps / mean 8.800000
# 34 Episode finished after 9.000000 time steps / mean 8.800000
# 35 Episode finished after 9.000000 time steps / mean 8.900000
# 36 Episode finished after 9.000000 time steps / mean 9.000000
# 37 Episode finished after 9.000000 time steps / mean 9.000000
# 38 Episode finished after 9.000000 time steps / mean 9.000000
# 39 Episode finished after 8.000000 time steps / mean 9.000000
# 40 Episode finished after 9.000000 time steps / mean 9.100000
# 41 Episode finished after 10.000000 time steps / mean 9.100000
# 42 Episode finished after 7.000000 time steps / mean 8.800000
# 43 Episode finished after 7.000000 time steps / mean 8.600000
# 44 Episode finished after 13.000000 time steps / mean 9.000000
# 45 Episode finished after 9.000000 time steps / mean 9.000000
# 46 Episode finished after 8.000000 time steps / mean 8.900000
# 47 Episode finished after 9.000000 time steps / mean 8.900000
# 48 Episode finished after 9.000000 time steps / mean 8.900000
# 49 Episode finished after 8.000000 time steps / mean 8.900000
# 50 Episode finished after 8.000000 time steps / mean 8.800000
# 51 Episode finished after 8.000000 time steps / mean 8.600000
# 52 Episode finished after 8.000000 time steps / mean 8.700000
# 53 Episode finished after 9.000000 time steps / mean 8.900000
# 54 Episode finished after 8.000000 time steps / mean 8.400000
# 55 Episode finished after 7.000000 time steps / mean 8.200000
# 56 Episode finished after 9.000000 time steps / mean 8.300000
# 57 Episode finished after 7.000000 time steps / mean 8.100000
# 58 Episode finished after 8.000000 time steps / mean 8.000000
# 59 Episode finished after 9.000000 time steps / mean 8.100000
# 60 Episode finished after 7.000000 time steps / mean 8.000000
# 61 Episode finished after 9.000000 time steps / mean 8.100000
# 62 Episode finished after 9.000000 time steps / mean 8.200000
# 63 Episode finished after 12.000000 time steps / mean 8.500000
# 64 Episode finished after 10.000000 time steps / mean 8.700000
# 65 Episode finished after 11.000000 time steps / mean 9.100000
# 66 Episode finished after 8.000000 time steps / mean 9.000000
# 67 Episode finished after 9.000000 time steps / mean 9.200000
# 68 Episode finished after 10.000000 time steps / mean 9.400000
# 69 Episode finished after 9.000000 time steps / mean 9.400000
# 70 Episode finished after 9.000000 time steps / mean 9.600000
# 71 Episode finished after 8.000000 time steps / mean 9.500000
# 72 Episode finished after 11.000000 time steps / mean 9.700000
# 73 Episode finished after 10.000000 time steps / mean 9.500000
# 74 Episode finished after 9.000000 time steps / mean 9.400000
# 75 Episode finished after 7.000000 time steps / mean 9.000000
# 76 Episode finished after 8.000000 time steps / mean 9.000000
# 77 Episode finished after 8.000000 time steps / mean 8.900000
# 78 Episode finished after 9.000000 time steps / mean 8.800000
# 79 Episode finished after 8.000000 time steps / mean 8.700000
# 80 Episode finished after 8.000000 time steps / mean 8.600000
# 81 Episode finished after 8.000000 time steps / mean 8.600000
# 82 Episode finished after 9.000000 time steps / mean 8.400000
# 83 Episode finished after 9.000000 time steps / mean 8.300000
# 84 Episode finished after 11.000000 time steps / mean 8.500000
# 85 Episode finished after 10.000000 time steps / mean 8.800000
# 86 Episode finished after 7.000000 time steps / mean 8.700000
# 87 Episode finished after 8.000000 time steps / mean 8.700000
# 88 Episode finished after 7.000000 time steps / mean 8.500000
# 89 Episode finished after 11.000000 time steps / mean 8.800000
# 90 Episode finished after 8.000000 time steps / mean 8.800000
# 91 Episode finished after 9.000000 time steps / mean 8.900000
# 92 Episode finished after 8.000000 time steps / mean 8.800000
# 93 Episode finished after 8.000000 time steps / mean 8.700000
# 94 Episode finished after 9.000000 time steps / mean 8.500000
# 95 Episode finished after 9.000000 time steps / mean 8.400000
# 96 Episode finished after 9.000000 time steps / mean 8.600000
# 97 Episode finished after 8.000000 time steps / mean 8.600000
# 98 Episode finished after 9.000000 time steps / mean 8.800000
# 99 Episode finished after 12.000000 time steps / mean 8.900000
# 100 Episode finished after 8.000000 time steps / mean 8.900000
# 101 Episode finished after 11.000000 time steps / mean 9.100000
# 102 Episode finished after 7.000000 time steps / mean 9.000000
# 103 Episode finished after 8.000000 time steps / mean 9.000000
# 104 Episode finished after 8.000000 time steps / mean 8.900000
# 105 Episode finished after 8.000000 time steps / mean 8.800000
# 106 Episode finished after 9.000000 time steps / mean 8.800000
# 107 Episode finished after 9.000000 time steps / mean 8.900000
# 108 Episode finished after 7.000000 time steps / mean 8.700000
# 109 Episode finished after 9.000000 time steps / mean 8.400000
# 110 Episode finished after 10.000000 time steps / mean 8.600000
# 111 Episode finished after 11.000000 time steps / mean 8.600000
# 112 Episode finished after 9.000000 time steps / mean 8.800000
# 113 Episode finished after 8.000000 time steps / mean 8.800000
# 114 Episode finished after 8.000000 time steps / mean 8.800000
# 115 Episode finished after 10.000000 time steps / mean 9.000000
# 116 Episode finished after 9.000000 time steps / mean 9.000000
# 117 Episode finished after 9.000000 time steps / mean 9.000000
# 118 Episode finished after 9.000000 time steps / mean 9.200000
# 119 Episode finished after 11.000000 time steps / mean 9.400000
# 120 Episode finished after 9.000000 time steps / mean 9.300000
# 121 Episode finished after 8.000000 time steps / mean 9.000000
# 122 Episode finished after 9.000000 time steps / mean 9.000000
# 123 Episode finished after 8.000000 time steps / mean 9.000000
# 124 Episode finished after 8.000000 time steps / mean 9.000000
# 125 Episode finished after 12.000000 time steps / mean 9.200000
# 126 Episode finished after 11.000000 time steps / mean 9.400000
# 127 Episode finished after 10.000000 time steps / mean 9.500000
# 128 Episode finished after 7.000000 time steps / mean 9.300000
# 129 Episode finished after 12.000000 time steps / mean 9.400000
# 130 Episode finished after 9.000000 time steps / mean 9.400000
# 131 Episode finished after 12.000000 time steps / mean 9.800000
# 132 Episode finished after 9.000000 time steps / mean 9.800000
# 133 Episode finished after 7.000000 time steps / mean 9.700000
# 134 Episode finished after 10.000000 time steps / mean 9.900000
# 135 Episode finished after 9.000000 time steps / mean 9.600000
# 136 Episode finished after 11.000000 time steps / mean 9.600000
# 137 Episode finished after 8.000000 time steps / mean 9.400000
# 138 Episode finished after 8.000000 time steps / mean 9.500000
# 139 Episode finished after 11.000000 time steps / mean 9.400000
# 140 Episode finished after 8.000000 time steps / mean 9.300000
# 141 Episode finished after 8.000000 time steps / mean 8.900000
# 142 Episode finished after 8.000000 time steps / mean 8.800000
# 143 Episode finished after 8.000000 time steps / mean 8.900000
# 144 Episode finished after 8.000000 time steps / mean 8.700000
# 145 Episode finished after 7.000000 time steps / mean 8.500000
# 146 Episode finished after 8.000000 time steps / mean 8.200000
# 147 Episode finished after 11.000000 time steps / mean 8.500000
# 148 Episode finished after 9.000000 time steps / mean 8.600000
# 149 Episode finished after 9.000000 time steps / mean 8.400000
# 150 Episode finished after 8.000000 time steps / mean 8.400000
# 151 Episode finished after 9.000000 time steps / mean 8.500000
# 152 Episode finished after 8.000000 time steps / mean 8.500000
# 153 Episode finished after 10.000000 time steps / mean 8.700000
# 154 Episode finished after 8.000000 time steps / mean 8.700000
# 155 Episode finished after 11.000000 time steps / mean 9.100000
# 156 Episode finished after 11.000000 time steps / mean 9.400000
# 157 Episode finished after 9.000000 time steps / mean 9.200000
# 158 Episode finished after 8.000000 time steps / mean 9.100000
# 159 Episode finished after 9.000000 time steps / mean 9.100000
# 160 Episode finished after 7.000000 time steps / mean 9.000000
# 161 Episode finished after 9.000000 time steps / mean 9.000000
# 162 Episode finished after 9.000000 time steps / mean 9.100000
# 163 Episode finished after 10.000000 time steps / mean 9.100000
# 164 Episode finished after 17.000000 time steps / mean 10.000000
# 165 Episode finished after 8.000000 time steps / mean 9.700000
# 166 Episode finished after 9.000000 time steps / mean 9.500000
# 167 Episode finished after 7.000000 time steps / mean 9.300000
# 168 Episode finished after 9.000000 time steps / mean 9.400000
# 169 Episode finished after 8.000000 time steps / mean 9.300000
# 170 Episode finished after 7.000000 time steps / mean 9.300000
# 171 Episode finished after 8.000000 time steps / mean 9.200000
# 172 Episode finished after 9.000000 time steps / mean 9.200000
# 173 Episode finished after 9.000000 time steps / mean 9.100000
# 174 Episode finished after 9.000000 time steps / mean 8.300000
# 175 Episode finished after 9.000000 time steps / mean 8.400000
# 176 Episode finished after 10.000000 time steps / mean 8.500000
# 177 Episode finished after 11.000000 time steps / mean 8.900000
# 178 Episode finished after 11.000000 time steps / mean 9.100000
# 179 Episode finished after 9.000000 time steps / mean 9.200000
# 180 Episode finished after 8.000000 time steps / mean 9.300000
# 181 Episode finished after 9.000000 time steps / mean 9.400000
# 182 Episode finished after 10.000000 time steps / mean 9.500000
# 183 Episode finished after 7.000000 time steps / mean 9.300000
# 184 Episode finished after 8.000000 time steps / mean 9.200000
# 185 Episode finished after 8.000000 time steps / mean 9.100000
# 186 Episode finished after 9.000000 time steps / mean 9.000000
# 187 Episode finished after 8.000000 time steps / mean 8.700000
# 188 Episode finished after 8.000000 time steps / mean 8.400000
# 189 Episode finished after 9.000000 time steps / mean 8.400000
# 190 Episode finished after 9.000000 time steps / mean 8.500000
# 191 Episode finished after 12.000000 time steps / mean 8.800000
# 192 Episode finished after 14.000000 time steps / mean 9.200000
# 193 Episode finished after 11.000000 time steps / mean 9.600000
# 194 Episode finished after 8.000000 time steps / mean 9.600000
# 195 Episode finished after 9.000000 time steps / mean 9.700000
# 196 Episode finished after 12.000000 time steps / mean 10.000000
# 197 Episode finished after 9.000000 time steps / mean 10.100000
# 198 Episode finished after 12.000000 time steps / mean 10.500000
# 199 Episode finished after 8.000000 time steps / mean 10.400000
# 200 Episode finished after 8.000000 time steps / mean 10.300000
# 201 Episode finished after 11.000000 time steps / mean 10.200000
# 202 Episode finished after 9.000000 time steps / mean 9.700000
# 203 Episode finished after 12.000000 time steps / mean 9.800000
# 204 Episode finished after 8.000000 time steps / mean 9.800000
# 205 Episode finished after 21.000000 time steps / mean 11.000000
# 206 Episode finished after 11.000000 time steps / mean 10.900000
# 207 Episode finished after 8.000000 time steps / mean 10.800000
# 208 Episode finished after 15.000000 time steps / mean 11.100000
# 209 Episode finished after 8.000000 time steps / mean 11.100000
# 210 Episode finished after 8.000000 time steps / mean 11.100000
# 211 Episode finished after 8.000000 time steps / mean 10.800000
# 212 Episode finished after 10.000000 time steps / mean 10.900000
# 213 Episode finished after 8.000000 time steps / mean 10.500000
# 214 Episode finished after 11.000000 time steps / mean 10.800000
# 215 Episode finished after 7.000000 time steps / mean 9.400000
# 216 Episode finished after 11.000000 time steps / mean 9.400000
# 217 Episode finished after 12.000000 time steps / mean 9.800000
# 218 Episode finished after 8.000000 time steps / mean 9.100000
# 219 Episode finished after 24.000000 time steps / mean 10.700000
# 220 Episode finished after 8.000000 time steps / mean 10.700000
# 221 Episode finished after 8.000000 time steps / mean 10.700000
# 222 Episode finished after 9.000000 time steps / mean 10.600000
# 223 Episode finished after 16.000000 time steps / mean 11.400000
# 224 Episode finished after 9.000000 time steps / mean 11.200000
# 225 Episode finished after 10.000000 time steps / mean 11.500000
# 226 Episode finished after 11.000000 time steps / mean 11.500000
# 227 Episode finished after 9.000000 time steps / mean 11.200000
# 228 Episode finished after 10.000000 time steps / mean 11.400000
# 229 Episode finished after 9.000000 time steps / mean 9.900000
# 230 Episode finished after 10.000000 time steps / mean 10.100000
# 231 Episode finished after 9.000000 time steps / mean 10.200000
# 232 Episode finished after 9.000000 time steps / mean 10.200000
# 233 Episode finished after 8.000000 time steps / mean 9.400000
# 234 Episode finished after 9.000000 time steps / mean 9.400000
# 235 Episode finished after 16.000000 time steps / mean 10.000000
# 236 Episode finished after 7.000000 time steps / mean 9.600000
# 237 Episode finished after 8.000000 time steps / mean 9.500000
# 238 Episode finished after 12.000000 time steps / mean 9.700000
# 239 Episode finished after 9.000000 time steps / mean 9.700000
# 240 Episode finished after 9.000000 time steps / mean 9.600000
# 241 Episode finished after 9.000000 time steps / mean 9.600000
# 242 Episode finished after 13.000000 time steps / mean 10.000000
# 243 Episode finished after 9.000000 time steps / mean 10.100000
# 244 Episode finished after 9.000000 time steps / mean 10.100000
# 245 Episode finished after 8.000000 time steps / mean 9.300000
# 246 Episode finished after 9.000000 time steps / mean 9.500000
# 247 Episode finished after 9.000000 time steps / mean 9.600000
# 248 Episode finished after 8.000000 time steps / mean 9.200000
# 249 Episode finished after 11.000000 time steps / mean 9.400000
# 250 Episode finished after 22.000000 time steps / mean 10.700000
# 251 Episode finished after 9.000000 time steps / mean 10.700000
# 252 Episode finished after 12.000000 time steps / mean 10.600000
# 253 Episode finished after 8.000000 time steps / mean 10.500000
# 254 Episode finished after 18.000000 time steps / mean 11.400000
# 255 Episode finished after 16.000000 time steps / mean 12.200000
# 256 Episode finished after 10.000000 time steps / mean 12.300000
# 257 Episode finished after 9.000000 time steps / mean 12.300000
# 258 Episode finished after 25.000000 time steps / mean 14.000000
# 259 Episode finished after 9.000000 time steps / mean 13.800000
# 260 Episode finished after 8.000000 time steps / mean 12.400000
# 261 Episode finished after 10.000000 time steps / mean 12.500000
# 262 Episode finished after 9.000000 time steps / mean 12.200000
# 263 Episode finished after 8.000000 time steps / mean 12.200000
# 264 Episode finished after 8.000000 time steps / mean 11.200000
# 265 Episode finished after 12.000000 time steps / mean 10.800000
# 266 Episode finished after 46.000000 time steps / mean 14.400000
# 267 Episode finished after 8.000000 time steps / mean 14.300000
# 268 Episode finished after 8.000000 time steps / mean 12.600000
# 269 Episode finished after 14.000000 time steps / mean 13.100000
# 270 Episode finished after 25.000000 time steps / mean 14.800000
# 271 Episode finished after 39.000000 time steps / mean 17.700000
# 272 Episode finished after 8.000000 time steps / mean 17.600000
# 273 Episode finished after 9.000000 time steps / mean 17.700000
# 274 Episode finished after 16.000000 time steps / mean 18.500000
# 275 Episode finished after 18.000000 time steps / mean 19.100000
# 276 Episode finished after 9.000000 time steps / mean 15.400000
# 277 Episode finished after 61.000000 time steps / mean 20.700000
# 278 Episode finished after 30.000000 time steps / mean 22.900000
# 279 Episode finished after 16.000000 time steps / mean 23.100000
# 280 Episode finished after 18.000000 time steps / mean 22.400000
# 281 Episode finished after 131.000000 time steps / mean 31.600000
# 282 Episode finished after 140.000000 time steps / mean 44.800000
# 283 Episode finished after 56.000000 time steps / mean 49.500000
# 284 Episode finished after 7.000000 time steps / mean 48.600000
# 285 Episode finished after 88.000000 time steps / mean 55.600000
# 286 Episode finished after 19.000000 time steps / mean 56.600000
# 287 Episode finished after 39.000000 time steps / mean 54.400000
# 288 Episode finished after 63.000000 time steps / mean 57.700000
# 289 Episode finished after 41.000000 time steps / mean 60.200000
# 290 Episode finished after 43.000000 time steps / mean 62.700000
# 291 Episode finished after 141.000000 time steps / mean 63.700000
# 292 Episode finished after 37.000000 time steps / mean 53.400000
# 293 Episode finished after 51.000000 time steps / mean 52.900000
# 294 Episode finished after 35.000000 time steps / mean 55.700000
# 295 Episode finished after 63.000000 time steps / mean 53.200000
# 296 Episode finished after 48.000000 time steps / mean 56.100000
# 297 Episode finished after 40.000000 time steps / mean 56.200000
# 298 Episode finished after 199.000000 time steps / mean 69.800000
